# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sf=sns.load_dataset('iris')
sf
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sf.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
sf['species'].value_counts()
# Out:
# 0.5    50
# 0.0    50
# 1.0    50
# Name: species, dtype: int64

# %%
sf.info
# Out:
# <bound method DataFrame.info of      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]>

# %%
sf.shape
# Out:
# (150, 5)

# %%
sf['species'].replace(['setosa','versicolor','virginica'],[1,0,0.5],inplace=True)

# %%
sf
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0             5.1          3.5           1.4          0.2      1.0
# 1             4.9          3.0           1.4          0.2      1.0
# 2             4.7          3.2           1.3          0.2      1.0
# 3             4.6          3.1           1.5          0.2      1.0
# 4             5.0          3.6           1.4          0.2      1.0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3      0.5
# 146           6.3          2.5           5.0          1.9      0.5
# 147           6.5          3.0           5.2          2.0      0.5
# 148           6.2          3.4           5.4          2.3      0.5
# 149           5.9          3.0           5.1          1.8      0.5
#
# [150 rows x 5 columns]

# %%
sns.jointplot(sf['petal_length'],sf['petal_width'],kind='reg')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.pairplot(sf,hue='species',size=2.5)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:1969: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.scatterplot(sf['petal_length'],sf['petal_width'],hue=sf['species'],color='b')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.scatterplot(sf['sepal_length'],sf['sepal_width'],hue=sf['species'],color='b')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sf
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0             5.1          3.5           1.4          0.2      1.0
# 1             4.9          3.0           1.4          0.2      1.0
# 2             4.7          3.2           1.3          0.2      1.0
# 3             4.6          3.1           1.5          0.2      1.0
# 4             5.0          3.6           1.4          0.2      1.0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3      0.5
# 146           6.3          2.5           5.0          1.9      0.5
# 147           6.5          3.0           5.2          2.0      0.5
# 148           6.2          3.4           5.4          2.3      0.5
# 149           5.9          3.0           5.1          1.8      0.5
#
# [150 rows x 5 columns]

# %%
insf=sf.drop('species',axis=1)
insf
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
outsf=sf['species']
outsf
# Out:
# 0      1.0
# 1      1.0
# 2      1.0
# 3      1.0
# 4      1.0
#       ...
# 145    0.5
# 146    0.5
# 147    0.5
# 148    0.5
# 149    0.5
# Name: species, Length: 150, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(insf,outsf,test_size=0.2,random_state=1)

# %%
from sklearn.linear_model import LinearRegression

# %%
linmodel=LinearRegression()

# %%
linmodel.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
predict=linmodel.predict(x_test)

# %%
list(zip(insf.columns,linmodel.coef_))
# Out:
# [('sepal_length', 0.001544385178535256),
#  ('sepal_width', 0.3747289380609826),
#  ('petal_length', -0.1802060958106429),
#  ('petal_width', 0.17063709710445896)]

# %%
linmodel.intercept_
# Out:
# -0.15350225681110174

# %%
pred_train=linmodel.predict(x_train)
pred_test=linmodel.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error
rmse_train=np.sqrt(mean_squared_error(y_train,pred_train))
rmse_test=np.sqrt(mean_squared_error(y_test,pred_test))
print(rmse_train,rmse_test)
# Out:
# 0.26477683751219055 0.2829987835997144

# %%
print({'actualunseendata':y_test,'predictedunseendata':pred_test})
# Out:
# {'actualunseendata': 14     1.0
# 98     0.0
# 75     0.0
# 16     1.0
# 131    0.5
# 56     0.0
# 141    0.5
# 44     1.0
# 29     1.0
# 120    0.5
# 94     0.0
# 5      1.0
# 102    0.5
# 51     0.0
# 78     0.0
# 42     1.0
# 92     0.0
# 66     0.0
# 31     1.0
# 35     1.0
# 90     0.0
# 84     0.0
# 77     0.0
# 40     1.0
# 125    0.5
# 99     0.0
# 33     1.0
# 19     1.0
# 73     0.0
# 146    0.5
# Name: species, dtype: float64, 'predictedunseendata': array([1.17225103, 0.43827897, 0.42686261, 1.1502672 , 0.47062353,
#        0.51888357, 0.49222794, 1.00420733, 0.79868662, 0.42157718,
#        0.33187706, 1.07818476, 0.27677163, 0.50054262, 0.38750619,
#        0.85228513, 0.31369055, 0.42436133, 0.92686151, 0.87123238,
#        0.2411448 , 0.42405245, 0.37008452, 0.98269416, 0.28266012,
#        0.387525  , 1.21069229, 1.05922606, 0.26295539, 0.21622972])}
